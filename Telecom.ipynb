# %% [markdown]
# <a href="https://colab.research.google.com/github/claudio1804-12/telecom_challenge/blob/main/Telecom.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-cursos/challenge2-data-science-LATAM/5adf5f2f87a72bd8b2e854db16e2f2f7c499081a/TelecomX_Data.json"
df = pd.read_json(url)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7267 non-null   object
#  1   Churn       7267 non-null   object
#  2   customer    7267 non-null   object
#  3   phone       7267 non-null   object
#  4   internet    7267 non-null   object
#  5   account     7267 non-null   object
# dtypes: object(6)
# memory usage: 340.8+ KB

# %%
unicos = df['customerID'].unique()
un = pd.value_counts(unicos)
un.max()
display(df)
# Out:
# /tmp/ipykernel_791/693526238.py:2: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   un = pd.value_counts(unicos)
#       customerID Churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# ...

# %%
df.describe()
# Out:
#         customerID Churn                                           customer  \
# count         7267  7267                                               7267
# unique        7267     3                                                891
# top     9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# freq             1  5174                                                223
#
#                                                  phone  \
# count                                             7267
# unique                                               3
# top     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# freq                                              3495
#
#                                                  internet  \
# count                                                7267
# unique                                                129
# top     {'InternetService': 'No', 'OnlineSecurity': 'N...
# freq                                                 1581
#
# ...

# %%
df_norm = pd.concat([df['customerID'], df['Churn'], pd.json_normalize(df['customer']), pd.json_normalize(df['phone']),
                     pd.json_normalize(df['internet']), pd.json_normalize(df['account'])], axis=1)
df_norm
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     0002-ORFBO    No  Female              0     Yes        Yes       9
# 1     0003-MKNFE    No    Male              0      No         No       9
# 2     0004-TLHLJ   Yes    Male              0      No         No       4
# 3     0011-IGKFF   Yes    Male              1     Yes         No      13
# 4     0013-EXCHZ   Yes  Female              1     Yes         No       3
# ...          ...   ...     ...            ...     ...        ...     ...
# 7262  9987-LUTYD    No  Female              0      No         No      13
# 7263  9992-RRAMN   Yes    Male              0     Yes         No      22
# 7264  9992-UJOEL    No    Male              0      No         No       2
# 7265  9993-LHIEB    No    Male              0     Yes        Yes      67
# 7266  9995-HOTOH    No    Male              0     Yes        Yes      63
#
#      PhoneService     MultipleLines InternetService  ... OnlineBackup  \
# ...

# %%
df_norm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
# ...

# %%
df_norm['Charges.Total'] = pd.to_numeric(df_norm['Charges.Total'], errors='coerce')
df_norm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
# ...

# %%
mask = pd.to_numeric(df_norm['Charges.Total'], errors='coerce').isna()
df_norm.loc[mask, 'Charges.Total']
df_norm[df_norm['Charges.Total'].isna()]
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 975   1371-DWPAZ    No  Female              0     Yes        Yes       0
# 1775  2520-SGTTA    No  Female              0     Yes        Yes       0
# 1955  2775-SEFEE    No    Male              0      No        Yes       0
# 2075  2923-ARZLG    No    Male              0     Yes        Yes       0
# 2232  3115-CZMZD    No    Male              0      No        Yes       0
# 2308  3213-VVOLG    No    Male              0     Yes        Yes       0
# 2930  4075-WKNIU    No  Female              0     Yes        Yes       0
# 3134  4367-NUYAO    No    Male              0     Yes        Yes       0
# 3203  4472-LVYGI    No  Female              0     Yes        Yes       0
# 4169  5709-LVOEQ    No  Female              0     Yes        Yes       0
# 5599  7644-OMVMY    No    Male              0     Yes        Yes       0
#
#      PhoneService     MultipleLines InternetService  ...         OnlineBackup  \
# ...

# %%
df_norm[df_norm['tenure'] == 0]
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 975   1371-DWPAZ    No  Female              0     Yes        Yes       0
# 1775  2520-SGTTA    No  Female              0     Yes        Yes       0
# 1955  2775-SEFEE    No    Male              0      No        Yes       0
# 2075  2923-ARZLG    No    Male              0     Yes        Yes       0
# 2232  3115-CZMZD    No    Male              0      No        Yes       0
# 2308  3213-VVOLG    No    Male              0     Yes        Yes       0
# 2930  4075-WKNIU    No  Female              0     Yes        Yes       0
# 3134  4367-NUYAO    No    Male              0     Yes        Yes       0
# 3203  4472-LVYGI    No  Female              0     Yes        Yes       0
# 4169  5709-LVOEQ    No  Female              0     Yes        Yes       0
# 5599  7644-OMVMY    No    Male              0     Yes        Yes       0
#
#      PhoneService     MultipleLines InternetService  ...         OnlineBackup  \
# ...

# %%
df_norm.loc[df_norm['tenure']==0,'Charges.Total']=0
df_norm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
# ...

# %%
col_name = df_norm.columns
for i in col_name:
  print(f'{i}: {df_norm[i].unique()}')
# Out:
# customerID: ['0002-ORFBO' '0003-MKNFE' '0004-TLHLJ' ... '9992-UJOEL' '9993-LHIEB'
#  '9995-HOTOH']
# Churn: ['No' 'Yes' '']
# gender: ['Female' 'Male']
# SeniorCitizen: [0 1]
# Partner: ['Yes' 'No']
# Dependents: ['Yes' 'No']
# tenure: [ 9  4 13  3 71 63  7 65 54 72  5 56 34  1 45 50 23 55 26 69 11 37 49 66
#  67 20 43 59 12 27  2 25 29 14 35 64 39 40  6 30 70 57 58 16 32 33 10 21
#  61 15 44 22 24 19 47 62 46 52  8 60 48 28 41 53 68 51 31 36 17 18 38 42
#   0]
# PhoneService: ['Yes' 'No']
# MultipleLines: ['No' 'Yes' 'No phone service']
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: ['No' 'Yes' 'No internet service']
# OnlineBackup: ['Yes' 'No' 'No internet service']
# DeviceProtection: ['No' 'Yes' 'No internet service']
# TechSupport: ['Yes' 'No' 'No internet service']
# StreamingTV: ['Yes' 'No' 'No internet service']
# StreamingMovies: ['No' 'Yes' 'No internet service']
# Contract: ['One year' 'Month-to-month' 'Two year']
# PaperlessBilling: ['Yes' 'No']
# ...

# %%
df_norm[df_norm['Churn'] == ""]
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 30    0047-ZHDTW        Female              0      No         No      11
# 75    0120-YZLQA          Male              0      No         No      71
# 96    0154-QYHJU          Male              0      No         No      29
# 98    0162-RZGMZ        Female              1      No         No       5
# 175   0274-VVQOQ          Male              1     Yes         No      65
# ...          ...   ...     ...            ...     ...        ...     ...
# 7158  9840-GSRFX        Female              0      No         No      14
# 7180  9872-RZQQB        Female              0     Yes         No      49
# 7211  9920-GNDMB          Male              0      No         No       9
# 7239  9955-RVWSC        Female              0     Yes        Yes      67
# 7247  9966-VYRTZ        Female              0     Yes        Yes      31
#
#      PhoneService     MultipleLines InternetService  ...         OnlineBackup  \
# ...

# %%
df_norm = df_norm[df_norm['Churn'].str.strip() != ""]
df_norm['Churn'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df_norm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   Churn             7043 non-null   object
#  2   gender            7043 non-null   object
#  3   SeniorCitizen     7043 non-null   int64
#  4   Partner           7043 non-null   object
#  5   Dependents        7043 non-null   object
#  6   tenure            7043 non-null   int64
#  7   PhoneService      7043 non-null   object
#  8   MultipleLines     7043 non-null   object
#  9   InternetService   7043 non-null   object
#  10  OnlineSecurity    7043 non-null   object
#  11  OnlineBackup      7043 non-null   object
#  12  DeviceProtection  7043 non-null   object
#  13  TechSupport       7043 non-null   object
#  14  StreamingTV       7043 non-null   object
#  15  StreamingMovies   7043 non-null   object
# ...

# %%
df_norm.describe()
# Out:
#        SeniorCitizen       tenure  Charges.Monthly  Charges.Total
# count    7043.000000  7043.000000      7043.000000    7043.000000
# mean        0.162147    32.371149        64.761692    2279.734304
# std         0.368612    24.559481        30.090047    2266.794470
# min         0.000000     0.000000        18.250000       0.000000
# 25%         0.000000     9.000000        35.500000     398.550000
# 50%         0.000000    29.000000        70.350000    1394.550000
# 75%         0.000000    55.000000        89.850000    3786.600000
# max         1.000000    72.000000       118.750000    8684.800000

# %%
from google.colab import files
df_norm.to_csv('df_norm.csv', index=False)
files.download('df_norm.csv')
import matplotlib.pyplot as plt
plt.pie(df_norm['Churn'].value_counts(), labels=df_norm['Churn'].value_counts().index, autopct='%1.1f%%')
plt.title('Distribución de Permanencia de Clientes en la Empresa')
# Out:
# Text(0.5, 1.0, 'Distribución de Permanencia de Clientes en la Empresa')

# %%
data = pd.crosstab(df_norm['Churn'], df_norm['SeniorCitizen'])
data.plot(kind='bar')

plt.title('Permanencia por Seniority')
plt.xlabel('Permanencia')
plt.ylabel('Cantidad de Clientes')
plt.xticks(rotation=0)

plt.show()

# %%
data = pd.crosstab(df_norm['Churn'], df_norm['InternetService'])
data.plot(kind='bar')

plt.title('Permanencia por Servicios Contratados')
plt.xlabel('Permanencia')
plt.ylabel('Cantidad de Clientes')
plt.xticks(rotation=0)

plt.show()

# %%
data = pd.crosstab(df_norm['Churn'], df_norm['Contract'])
data.plot(kind='bar')

plt.title('Permanencia por Contrato')
plt.xlabel('Permanencia')
plt.ylabel('Cantidad de Clientes')
plt.xticks(rotation=0)

plt.show()

# %%
fig, ax = plt.subplots()

no = df_norm[df_norm['Churn'] == 'No']
si = df_norm[df_norm['Churn'] == 'Yes']

ax.scatter(no['tenure'], no['Charges.Total'], color='blue', label='No')
ax.scatter(si['tenure'], si['Charges.Total'], color='red', label='Si')

ax.set_title('Dispersión de Clientes según Permanencia')
ax.set_xlabel('Permanencia (meses)')
ax.set_ylabel('Gasto Total')
ax.legend()
plt.show()

# %%
intro = 'INTRODUCCIÓN: El objetivo es comprender las razones de los clientes de abandonar la empresa, análisis y el problema de evasión de clientes que se evalúa a partir de información otorgada a través de api.'
tratamiento = 'Luego de obterner la información a través de la api, se procede a revisar las tablas y a corregir algunos problemas, tales como celdas vacías, columnas con valores faltantes, etc.'
analisis = 'Se realiza análisis exploratorio de los datos utilizando gráficos de torta, de barras apiladas y de dispersión de las cifras, los cuales se observan a cotninuación:'
conclusion = 'Lo anterior es un reflejo de que los cliente que dejaron la empresa son aquellos que contaban con contratos cortos y pagaban un costo total alto, a pesar de tener contratos renovables mes a mes.'
consejo = 'CONSEJO: Por lo tanto, para reducir la evasión haría ofertas a los clientes que renuevan mensualmente sus contratos y que tengan mayor permanencia en la empresa.'

print(intro)

print(tratamiento)

print(analisis)

print(conclusion)

print(consejo)
# Out:
# INTRODUCCIÓN: El objetivo es comprender las razones de los clientes de abandonar la empresa, análisis y el problema de evasión de clientes que se evalúa a partir de información otorgada a través de api.
# Luego de obterner la información a través de la api, se procede a revisar las tablas y a corregir algunos problemas, tales como celdas vacías, columnas con valores faltantes, etc.
# Se realiza análisis exploratorio de los datos utilizando gráficos de torta, de barras apiladas y de dispersión de las cifras, los cuales se observan a cotninuación:
# Lo anterior es un reflejo de que los cliente que dejaron la empresa son aquellos que contaban con contratos cortos y pagaban un costo total alto, a pesar de tener contratos renovables mes a mes.
# CONSEJO: Por lo tanto, para reducir la evasión haría ofertas a los clientes que renuevan mensualmente sus contratos y que tengan mayor permanencia en la empresa.
